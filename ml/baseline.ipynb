# %%
import os
from pathlib import Path

import pandas as pd
import geopandas as gpd
from dbfread import DBF

# %%
DATA_PATH = Path(os.getcwd()) / "dataset"

# %%
list(DATA_PATH.iterdir())

# %%
names = set()
for file in DATA_PATH.iterdir():
    names.add(file.suffix)
names
# Out:
# {'.cpg', '.dbf', '.docx', '.prj', '.qmd', '.shp', '.shx'}

# %%
for record in DBF(DATA_PATH / "House_1очередь_ЖК.dbf", encoding="utf-8"):
    print(record)
# Out:
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Малоэтажный жилой дом', 'Elevation': 3, 'Entrances': 4, 'Apartments': 86, 'District': 'Коммунарка', 'Street': 'Потаповская Роща', 'Number': '2 к3'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Малоэтажный жилой дом', 'Elevation': 3, 'Entrances': 4, 'Apartments': 86, 'District': 'Коммунарка', 'Street': 'Потаповская Роща', 'Number': '1 к2'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Малоэтажный жилой дом', 'Elevation': 3, 'Entrances': 4, 'Apartments': 86, 'District': 'Коммунарка', 'Street': 'Потаповская Роща', 'Number': '1 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Малоэтажный жилой дом', 'Elevation': 3, 'Entrances': 4, 'Apartments': 86, 'District': 'Коммунарка', 'Street': 'Потаповская Роща', 'Number': '3 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Малоэтажный жилой дом', 'Elevation': 3, 'Entrances': 3, 'Apartments': 98, 'District': 'Коммунарка', 'Street': 'Потаповская Роща', 'Number': '2 к4'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Малоэтажный жилой дом', 'Elevation': 3, 'Entrances': 4, 'Apartments': 66, 'District': 'Коммунарка', 'Street': 'Потаповская Роща', 'Number': '2 к2'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Малоэтажный жилой дом', 'Elevation': 3, 'Entrances': 4, 'Apartments': 96, 'District': 'Коммунарка', 'Street': 'Потаповская Роща', 'Number': '2 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Малоэтажный жилой дом', 'Elevation': 3, 'Entrances': 4, 'Apartments': 86, 'District': 'Коммунарка', 'Street': 'Потаповская Роща', 'Number': '3 к2'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 18, 'Entrances': 6, 'Apartments': 399, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '88 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 18, 'Entrances': 6, 'Apartments': 382, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '88 к2'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 18, 'Entrances': 2, 'Apartments': 306, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '88 к3'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 18, 'Entrances': 3, 'Apartments': 297, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '90 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 18, 'Entrances': 6, 'Apartments': 365, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '90 к2'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 1, 'Apartments': 162, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '90 к5'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 1, 'Apartments': 162, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '90 к6'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 18, 'Entrances': 5, 'Apartments': 400, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '90 к3'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 18, 'Entrances': 6, 'Apartments': 392, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '90 к4'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 4, 'Apartments': 354, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '84 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 4, 'Apartments': 354, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '84 к2'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 4, 'Apartments': 354, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '84 к4'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 4, 'Apartments': 354, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '84 к3'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 6, 'Apartments': 408, 'District': 'Коммунарка', 'Street': 'Куприна проспект', 'Number': '24 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 5, 'Apartments': 426, 'District': 'Коммунарка', 'Street': 'Куприна проспект', 'Number': '24 к2'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 4, 'Apartments': 624, 'District': 'Коммунарка', 'Street': 'Куприна проспект', 'Number': '24 к3'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 2, 'Apartments': 373, 'District': 'Коммунарка', 'Street': 'Куприна проспект', 'Number': '18 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 4, 'Apartments': 298, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '91 к2'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 3, 'Apartments': 336, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '91 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 4, 'Apartments': 312, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '89 к1'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 17, 'Entrances': 2, 'Apartments': 242, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '89 к2'})
# OrderedDict({'Type': 'Жилые дома', 'Purpose': 'Жилой дом', 'Elevation': 18, 'Entrances': 2, 'Apartments': 370, 'District': 'Коммунарка', 'Street': 'Куприна проспект', 'Number': '18 к2'})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Сооружение', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Автостоянка', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Сооружение', 'Elevation': 5, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '82а ст2'})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 4, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Сооружение', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': 'Александры Монаховой', 'Number': '82а ст1'})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Автостоянка', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})
# OrderedDict({'Type': 'Известный по назначению', 'Purpose': 'Хозяйственный корпус', 'Elevation': 1, 'Entrances': None, 'Apartments': None, 'District': 'Коммунарка', 'Street': '', 'Number': ''})

# %%
import os
from pathlib import Path
import geopandas as gpd
import pandas as pd
from dbfread import DBF
from typing import Dict, List, Union
from collections import OrderedDict

# .cpg parser
def parse_cpg(file_path: str) -> str:
    with open(file_path, 'r') as f:
        return f.read().strip()

# .dbf parser
def parse_dbf(file_path: str) -> DBF:
    return DBF(file_path, encoding='utf-8')

# .prj parser
def parse_prj(file_path: str) -> str:
    with open(file_path, 'r') as f:
        return f.read().strip()

# .qmd parser
def parse_qmd(file_path: str) -> str:
    with open(file_path, 'r') as f:
        return f.read()

# .shp parser
def parse_shp(file_path: str) -> gpd.GeoDataFrame:
    return gpd.read_file(file_path)

# .shx parser
def parse_shx(file_path: str) -> bytes:
    with open(file_path, 'rb') as f:
        return f.read()

# Process all files in folder
def parse_files_in_folder(folder_path: str) -> Dict[str, Union[str, pd.DataFrame, gpd.GeoDataFrame, bytes]]:
    parsed_data = {}
    for file in os.listdir(folder_path):
        file_path = Path(folder_path) / file
        print(f"Checking {file_path.name}...")
        ext = file_path.suffix.lower()
        match ext:
            case '.cpg':
                item  = parse_cpg(file_path)
            case '.dbf':
                item = parse_dbf(file_path)
            case '.prj':
                item = parse_prj(file_path)
            case '.qmd':
                item = parse_qmd(file_path)
            case '.shp':
                item = parse_shp(file_path)
            case '.shx':
                item = parse_shx(file_path)
            case _:
                item = None
        parsed_data[file_path.stem] = item
    return parsed_data

# %%
df = parse_files_in_folder(DATA_PATH)

# %%
df.keys()
# Out:
# dict_keys(['House_3очередь_ЖК', 'Остановки_ОТ', 'Streets_2очередь', 'Streets_1очередь', 'Дома_исходные', 'Выходы_метро', 'Streets_исходные', 'House_1очередь_ЖК', 'Streets_3очередь', 'House_2очередь_ЖК', 'ЦОДД_описание атрибутов'])

# %%
df['Streets_3очередь']
# Out:
#       ST_NAME ST_TYP_BEF ST_NM_BASE                 ROAD_CATEG RoadDirect  \
# 0        None       None       None  Внутриквартальные проезды        Any
# 1        None       None       None  Внутриквартальные проезды        Any
# 2        None       None       None  Внутриквартальные проезды        Any
# 3        None       None       None  Внутриквартальные проезды        Any
# 4        None       None       None  Внутриквартальные проезды        Any
# ...       ...        ...        ...                        ...        ...
# 28812    None       None       None  Внутриквартальные проезды        Any
# 28813    None       None       None  Внутриквартальные проезды        Any
# 28814    None       None       None  Внутриквартальные проезды        Any
# 28815    None       None       None  Внутриквартальные проезды        Any
# 28816    None       None       None  Внутриквартальные проезды        Any
#
#        RbndStght  RbndBck  Width  MaxSpdDrct  AvgSpdDrct  MaxSpdRvrs  \
# 0            1.0      1.0    6.0          20          20          20
# 1            1.0      1.0    6.0          20          20          20
# 2            1.0      1.0    6.0          20          20          20
# 3            1.0      1.0    6.0          20          20          20
# 4            1.0      1.0    6.0          20          20          20
# ...          ...      ...    ...         ...         ...         ...
# 28812        1.0      1.0    6.0          20          20          20
# 28813        1.0      1.0    6.0          20          20          20
# 28814        1.0      1.0    6.0          20          20          20
# 28815        1.0      1.0    6.0          20          20          20
# 28816        1.0      1.0    6.0          20          20          20
#
#        AvgSpdRvrs  Foot  Car  \
# 0              20     1    1
# 1              20     1    1
# 2              20     1    1
# 3              20     1    1
# 4              20     1    1
# ...           ...   ...  ...
# 28812          20     1    1
# 28813          20     1    1
# 28814          20     1    1
# 28815          20     1    1
# 28816          20     1    1
#
#                                                 geometry
# 0      LINESTRING (4169313.05 7459602.18, 4169363.29 ...
# 1      LINESTRING (4169368.91 7459679.52, 4169357.17 ...
# 2      LINESTRING (4167431.36 7459646.24, 4167516.42 ...
# 3      LINESTRING (4169499.07 7459820.14, 4169493.58 ...
# 4      LINESTRING (4169053.72 7459877.54, 4169260.2 7...
# ...                                                  ...
# 28812  LINESTRING (4171555.24 7477440.42, 4171562.64 ...
# 28813  LINESTRING (4171562.64 7477460.78, 4171587.9 7...
# 28814  LINESTRING (4171773.99 7477765.8, 4171810.92 7...
# 28815  LINESTRING (4171773.99 7477765.8, 4171906.15 7...
# 28816  LINESTRING (4171726.9 7477667.3, 4171714.01 74...
#
# [28817 rows x 15 columns]

# %%
gpd.read_file(DATA_PATH / "House_1очередь_ЖК.shp")
# Out:
#                        Type                Purpose  Elevation  Entrances  \
# 0                Жилые дома  Малоэтажный жилой дом          3        4.0
# 1                Жилые дома  Малоэтажный жилой дом          3        4.0
# 2                Жилые дома  Малоэтажный жилой дом          3        4.0
# 3                Жилые дома  Малоэтажный жилой дом          3        4.0
# 4                Жилые дома  Малоэтажный жилой дом          3        3.0
# 5                Жилые дома  Малоэтажный жилой дом          3        4.0
# 6                Жилые дома  Малоэтажный жилой дом          3        4.0
# 7                Жилые дома  Малоэтажный жилой дом          3        4.0
# 8                Жилые дома              Жилой дом         18        6.0
# 9                Жилые дома              Жилой дом         18        6.0
# 10               Жилые дома              Жилой дом         18        2.0
# 11               Жилые дома              Жилой дом         18        3.0
# 12               Жилые дома              Жилой дом         18        6.0
# 13               Жилые дома              Жилой дом         17        1.0
# 14               Жилые дома              Жилой дом         17        1.0
# 15               Жилые дома              Жилой дом         18        5.0
# 16               Жилые дома              Жилой дом         18        6.0
# 17               Жилые дома              Жилой дом         17        4.0
# 18               Жилые дома              Жилой дом         17        4.0
# 19               Жилые дома              Жилой дом         17        4.0
# 20               Жилые дома              Жилой дом         17        4.0
# 21               Жилые дома              Жилой дом         17        6.0
# 22               Жилые дома              Жилой дом         17        5.0
# 23               Жилые дома              Жилой дом         17        4.0
# 24               Жилые дома              Жилой дом         17        2.0
# 25               Жилые дома              Жилой дом         17        4.0
# 26               Жилые дома              Жилой дом         17        3.0
# 27               Жилые дома              Жилой дом         17        4.0
# 28               Жилые дома              Жилой дом         17        2.0
# 29               Жилые дома              Жилой дом         18        2.0
# 30  Известный по назначению   Хозяйственный корпус          1        NaN
# 31  Известный по назначению             Сооружение          1        NaN
# 32  Известный по назначению   Хозяйственный корпус          1        NaN
# 33  Известный по назначению            Автостоянка          1        NaN
# 34  Известный по назначению             Сооружение          5        NaN
# 35  Известный по назначению   Хозяйственный корпус          4        NaN
# 36  Известный по назначению   Хозяйственный корпус          1        NaN
# 37  Известный по назначению   Хозяйственный корпус          1        NaN
# 38  Известный по назначению   Хозяйственный корпус          1        NaN
# 39  Известный по назначению   Хозяйственный корпус          1        NaN
# 40  Известный по назначению             Сооружение          1        NaN
# 41  Известный по назначению   Хозяйственный корпус          1        NaN
# 42  Известный по назначению   Хозяйственный корпус          1        NaN
# 43  Известный по назначению            Автостоянка          1        NaN
# 44  Известный по назначению   Хозяйственный корпус          1        NaN
#
#     Apartments    District                Street   Number  \
# 0         86.0  Коммунарка      Потаповская Роща     2 к3
# 1         86.0  Коммунарка      Потаповская Роща     1 к2
# 2         86.0  Коммунарка      Потаповская Роща     1 к1
# 3         86.0  Коммунарка      Потаповская Роща     3 к1
# 4         98.0  Коммунарка      Потаповская Роща     2 к4
# 5         66.0  Коммунарка      Потаповская Роща     2 к2
# 6         96.0  Коммунарка      Потаповская Роща     2 к1
# 7         86.0  Коммунарка      Потаповская Роща     3 к2
# 8        399.0  Коммунарка  Александры Монаховой    88 к1
# 9        382.0  Коммунарка  Александры Монаховой    88 к2
# 10       306.0  Коммунарка  Александры Монаховой    88 к3
# 11       297.0  Коммунарка  Александры Монаховой    90 к1
# 12       365.0  Коммунарка  Александры Монаховой    90 к2
# 13       162.0  Коммунарка  Александры Монаховой    90 к5
# 14       162.0  Коммунарка  Александры Монаховой    90 к6
# 15       400.0  Коммунарка  Александры Монаховой    90 к3
# 16       392.0  Коммунарка  Александры Монаховой    90 к4
# 17       354.0  Коммунарка  Александры Монаховой    84 к1
# 18       354.0  Коммунарка  Александры Монаховой    84 к2
# 19       354.0  Коммунарка  Александры Монаховой    84 к4
# 20       354.0  Коммунарка  Александры Монаховой    84 к3
# 21       408.0  Коммунарка      Куприна проспект    24 к1
# 22       426.0  Коммунарка      Куприна проспект    24 к2
# 23       624.0  Коммунарка      Куприна проспект    24 к3
# 24       373.0  Коммунарка      Куприна проспект    18 к1
# 25       298.0  Коммунарка  Александры Монаховой    91 к2
# 26       336.0  Коммунарка  Александры Монаховой    91 к1
# 27       312.0  Коммунарка  Александры Монаховой    89 к1
# 28       242.0  Коммунарка  Александры Монаховой    89 к2
# 29       370.0  Коммунарка      Куприна проспект    18 к2
# 30         NaN  Коммунарка                  None     None
# 31         NaN  Коммунарка                  None     None
# 32         NaN  Коммунарка                  None     None
# 33         NaN  Коммунарка                  None     None
# 34         NaN  Коммунарка  Александры Монаховой  82а ст2
# 35         NaN  Коммунарка                  None     None
# 36         NaN  Коммунарка                  None     None
# 37         NaN  Коммунарка                  None     None
# 38         NaN  Коммунарка                  None     None
# 39         NaN  Коммунарка                  None     None
# 40         NaN  Коммунарка  Александры Монаховой  82а ст1
# 41         NaN  Коммунарка                  None     None
# 42         NaN  Коммунарка                  None     None
# 43         NaN  Коммунарка                  None     None
# 44         NaN  Коммунарка                  None     None
#
#                                              geometry
# 0   POLYGON ((4174099 7468553.82, 4174054.11 74684...
# 1   POLYGON ((4173865 7468327.02, 4173908.89 74683...
# 2   POLYGON ((4174008.05 7468232.57, 4173991.51 74...
# 3   POLYGON ((4173744.26 7468440.36, 4173741.92 74...
# 4   POLYGON ((4174166.95 7468519.72, 4174167.88 74...
# 5   POLYGON ((4173924.73 7468487.08, 4173936.06 74...
# 6   POLYGON ((4173799.11 7468576.63, 4173812.73 74...
# 7   POLYGON ((4173594.11 7468544.83, 4173564.48 74...
# 8   MULTIPOLYGON (((4172984.27 7468324.11, 4172933...
# 9   MULTIPOLYGON (((4172836.3 7468190.05, 4172861....
# 10  MULTIPOLYGON (((4172732.08 7468197.53, 4172751...
# 11  MULTIPOLYGON (((4172666.74 7468083.87, 4172641...
# 12  MULTIPOLYGON (((4172506.57 7468146.89, 4172498...
# 13  POLYGON ((4172109.44 7468010.17, 4172129 74679...
# 14  POLYGON ((4172021.77 7467977.68, 4172041.34 74...
# 15  MULTIPOLYGON (((4172304.56 7468101.02, 4172380...
# 16  MULTIPOLYGON (((4172332.55 7467892.08, 4172256...
# 17  MULTIPOLYGON (((4172613.07 7468455.56, 4172637...
# 18  MULTIPOLYGON (((4172715.42 7468431.33, 4172766...
# 19  MULTIPOLYGON (((4172415.46 7468291.82, 4172386...
# 20  MULTIPOLYGON (((4172498.66 7468541.27, 4172527...
# 21  MULTIPOLYGON (((4172236.39 7468444.09, 4172261...
# 22  MULTIPOLYGON (((4172136.79 7468188.66, 4172107...
# 23  MULTIPOLYGON (((4172021.75 7468146.07, 4172015...
# 24  MULTIPOLYGON (((4173247.4 7468759.71, 4173283....
# 25  MULTIPOLYGON (((4173187.59 7468958, 4173212.41...
# 26  MULTIPOLYGON (((4173150.45 7468916.02, 4173100...
# 27  MULTIPOLYGON (((4173076.01 7469118.37, 4173028...
# 28  MULTIPOLYGON (((4173135.27 7469095.04, 4173161...
# 29  MULTIPOLYGON (((4173174.6 7468732.83, 4173194....
# 30  POLYGON ((4174003.46 7468414.33, 4174004.3 746...
# 31  POLYGON ((4172632.59 7468003.35, 4172629.53 74...
# 32  POLYGON ((4172795.28 7468067.56, 4172798.59 74...
# 33  POLYGON ((4172113.79 7467812.09, 4172120.41 74...
# 34  POLYGON ((4171745.05 7468365.72, 4171740.15 74...
# 35  POLYGON ((4172877.25 7468480.91, 4172961.59 74...
# 36  POLYGON ((4172466.94 7468320.34, 4172475.21 74...
# 37  POLYGON ((4172480.42 7467958.51, 4172472.15 74...
# 38  POLYGON ((4172124.66 7467929.42, 4172128.34 74...
# 39  POLYGON ((4172248.82 7468471.37, 4172246.98 74...
# 40  POLYGON ((4171743.11 7468471.71, 4171762.68 74...
# 41  POLYGON ((4173089.53 7469149.72, 4173092.57 74...
# 42  POLYGON ((4171795.89 7468314.54, 4171792.79 74...
# 43  POLYGON ((4171822.07 7468148.07, 4171828.11 74...
# 44  POLYGON ((4172843.04 7468471.99, 4172852.83 74...

# %%
gpd.read_file(DATA_PATH / "House_3очередь_ЖК.shp")
# Out:
#     Type Purpose  Elevation  Entrances  Apartments    District  \
# 0  Школы   Школа          2        NaN         NaN  Коммунарка
# 1  Школы   Школа          3        NaN         NaN  Коммунарка
# 2  Школы   Школа          4        NaN         NaN  Коммунарка
#
#                  Street  Number  \
# 0      Потаповская Роща    2 к5
# 1  Александры Монаховой     96а
# 2      Куприна проспект  24 ст4
#
#                                             geometry
# 0  POLYGON ((4173932.77 7468595.71, 4173947.46 74...
# 1  MULTIPOLYGON (((4173174.84 7467838.91, 4173121...
# 2  POLYGON ((4171929.5 7468434.42, 4171913.59 746...

# %%
gpd.read_file(DATA_PATH / "House_3очередь_ЖК.shx")
# Out:
#     Type Purpose  Elevation  Entrances  Apartments    District  \
# 0  Школы   Школа          2        NaN         NaN  Коммунарка
# 1  Школы   Школа          3        NaN         NaN  Коммунарка
# 2  Школы   Школа          4        NaN         NaN  Коммунарка
#
#                  Street  Number  \
# 0      Потаповская Роща    2 к5
# 1  Александры Монаховой     96а
# 2      Куприна проспект  24 ст4
#
#                                             geometry
# 0  POLYGON ((4173932.77 7468595.71, 4173947.46 74...
# 1  MULTIPOLYGON (((4173174.84 7467838.91, 4173121...
# 2  POLYGON ((4171929.5 7468434.42, 4171913.59 746...

# %%
import os
import geopandas as gpd

def parse_gis_data(data_dir):
    """
    Parse a GIS dataset located in the given directory.
    
    Parameters:
    data_dir (str): Path to the directory containing the GIS files.
    
    Returns:
    geopandas.GeoDataFrame: A GeoDataFrame containing the GIS data.
    """
    # Find all the relevant GIS files in the directory
    gis_files = [f for f in os.listdir(data_dir) if any(f.endswith(ext) for ext in ['.shp', '.dbf', '.shx', '.prj'])]

    # Load the GIS data into a GeoDataFrame
    gdf = gpd.read_file(os.path.join(data_dir, [f for f in gis_files if f.endswith('.shp')][0]))

    return gdf


gdf = parse_gis_data(DATA_PATH)

# Explore the GeoDataFrame
print(gdf.head())
print(gdf.info())
# Out:
#                  TrType                      Name          TrStopId  \
# 0  Автобусная остановка                д. Дудкино  4504282527175082
# 1  Автобусная остановка        Академика Семёнова  4504282527177280
# 2  Автобусная остановка           СНТ Гавриково-1  4504282527177281
# 3  Автобусная остановка  СНТ Берёзка-Коммунарка-1  4504282549350453
# 4  Автобусная остановка  СНТ Берёзка-Коммунарка-1  4504282549350455
#
#                         geometry
# 0   POINT (4169298.8 7486206.48)
# 1  POINT (4175492.12 7468089.68)
# 2  POINT (4174773.19 7467701.78)
# 3  POINT (4173317.02 7470985.86)
# 4  POINT (4173231.61 7471209.38)
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TrType    61 non-null     object
#  1   Name      61 non-null     object
#  2   TrStopId  61 non-null     object
#  3   geometry  61 non-null     geometry
# dtypes: geometry(1), object(3)
# memory usage: 2.0+ KB
# None

# %%
gdf
# Out:
#                   TrType                       Name           TrStopId  \
# 0   Автобусная остановка                 д. Дудкино   4504282527175082
# 1   Автобусная остановка         Академика Семёнова   4504282527177280
# 2   Автобусная остановка            СНТ Гавриково-1   4504282527177281
# 3   Автобусная остановка   СНТ Берёзка-Коммунарка-1   4504282549350453
# 4   Автобусная остановка   СНТ Берёзка-Коммунарка-1   4504282549350455
# ..                   ...                        ...                ...
# 56  Автобусная остановка  Метро Новомосковская · 2B  70030076182590875
# 57  Автобусная остановка         Остановочный пункт  70030076948540367
# 58  Автобусная остановка         Остановочный пункт  70030076948540429
# 59  Автобусная остановка         Остановочный пункт  70030076948540491
# 60  Автобусная остановка         Остановочный пункт  70030076954657232
#
#                          geometry
# 0    POINT (4169298.8 7486206.48)
# 1   POINT (4175492.12 7468089.68)
# 2   POINT (4174773.19 7467701.78)
# 3   POINT (4173317.02 7470985.86)
# 4   POINT (4173231.61 7471209.38)
# ..                            ...
# 56  POINT (4171359.52 7471032.31)
# 57  POINT (4174177.65 7470593.46)
# 58  POINT (4174474.04 7470894.07)
# 59   POINT (4174353.06 7470784.1)
# 60  POINT (4174665.15 7470985.88)
#
# [61 rows x 4 columns]
